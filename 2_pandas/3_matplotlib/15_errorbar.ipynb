# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 10)
y = np.sin(x)
yerr = 0.1  
np.random.rand(10)
plt.errorbar(x, y, yerr=yerr, xerr=0.2 ,fmt='o', ecolor='red', capsize=5)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Error Bar Plot')
plt.grid(True)
plt.show()
